# %%
# %load_ext autoreload
# %autoreload 2

# %%
from src.plot import plot_multi
from config.experiments.minigrid_n6s10_bebold_only import config
plot_multi(config, err_type='area', max_step=20000000, interval=200000, num_col=1, width=4, height=3.5, legend_idx=0)
# Out:
# last step x 19800000
# last step y 0.6255769431591034
# average reward 0.6255769431591034 std 0.0

# %%
from src.plot import plot_multi
from config.experiments.minigrid_n6s10_bebold_cbet import config
plot_multi(config, err_type='area', max_step=20000000, interval=200000, num_col=1, width=4, height=3.5, legend_idx=1)
# Out:
# last step x 19800000
# last step y 0.6255769431591034
# average reward 0.6255769431591034 std 0.0
# last step x 9800000
# last step y 0.7766188383102417
# average reward 0.7766188383102417 std 0.0

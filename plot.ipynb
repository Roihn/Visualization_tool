# %%
# %load_ext autoreload
# %autoreload 2

# %%
from config.experiments.minigrid_n7s4_bebold_cbet import config
from src.plot import plot_multi

plot_multi(config, err_type='area', max_step=5e7, interval=1e5, num_col=1, width=4, height=3.5, legend_idx=1)
# Out:
# last step x 22000000.0
# last step y 0.7798556089401245
# average reward 0.7798556089401245 std 0.0
# last step x 49900000.0
# last step y 0.7772906422615051
# average reward 0.7772906422615051 std 0.0

# %%
from config.experiments.minigrid_multienv_pre_trained_extrinsic_cbet import config
from src.plot import plot_multi

plot_multi(config, err_type='area', max_step=5e7, interval=1e6, num_col=1, width=4, height=3.5, legend_idx=1)
# Out:
# last step x 49000000.0
# last step y 0.00130109037854705
# average reward 0.00130109037854705 std 0.0

# %%
from config.experiments.minigrid_n12s10_bebold_only import config
from src.plot import plot_multi

plot_multi(config, err_type='area', max_step=5e7, interval=1e5, num_col=1, width=4, height=3.5, legend_idx=1)
# Out:
# last step x 33400000.0
# last step y 0.64594966173172
# average reward 0.64594966173172 std 0.0

# %%
from config.experiments.minigrid_ObstructedMaze_bebold_only import config
from src.plot import plot_multi

plot_multi(config, err_type='area', max_step=6e7, interval=1e5, num_col=1, width=4, height=3.5, legend_idx=1)
# Out:
# last step x 49000000.0
# last step y 0.0
# average reward 0.0 std 0.0

# %%
from config.experiments.minigrid_KeyCorridor_bebold_only import config
from src.plot import plot_multi

plot_multi(config, err_type='area', max_step=4e7, interval=1e5, num_col=1, width=4, height=3.5, legend_idx=1)
# Out:
# last step x 39200000.0
# last step y 0.945916712284088
# average reward 0.945916712284088 std 0.0

# %%
from config.experiments.minigrid_multiroom_bebold_only import config
from src.plot import plot_multi

plot_multi(config, err_type='area', max_step=2e7, interval=5e4, num_col=1, width=4, height=3.5, legend_idx=1)
# Out:
# last step x 19950000.0
# last step y 0.6333653852343559
# average reward 0.6333653852343559 std 0.0
# last step x 19950000.0
# last step y 0.7673227488994598
# average reward 0.7673227488994598 std 0.0
# last step x 8850000.0
# last step y 0.6172278001904488
# average reward 0.6172278001904488 std 0.0
# last step x 8950000.0
# last step y 0.6621588319540024
# average reward 0.6621588319540024 std 0.0

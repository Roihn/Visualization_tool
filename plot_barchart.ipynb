# %%
# %load_ext autoreload
# %autoreload 2

# %%
from config.barchart.multiroom_cbet_vssum_vsratio import config
from src.plot_barchart import plot_barchart

for metric in config["metrics"]:
    plot_barchart(config, metric)
